# %%
import pandas as pd

layers = 12
df = pd.DataFrame()
for layer in range(layers):
    file = f'./results/wav2vecbase_perclass_{layer}.csv '
    data = pd.read_csv(file)
    data['layer'] = layer
    df = pd.concat([data, df], ignore_index=True)
df['accuracy'] = df['accuracy'].round(2)
df.head()
# Out:
#         class  accuracy  layer
# 0       angry      0.32     11
# 1  disgusting      0.36     11
# 2     fearful      0.81     11
# 3       happy      0.50     11
# 4     neutral      0.54     11

# %%
newdf = pd.pivot(df, index='layer', columns='class', values='accuracy')
newdf
# Out:
# class  angry  disgusting  fearful  happy  neutral   sad  surprise
# layer
# 0       0.52        0.23     0.75   0.36     0.85  0.67      0.69
# 1       0.36        0.36     0.88   0.64     1.00  0.47      0.92
# 2       0.72        0.27     0.88   0.50     0.85  0.53      0.92
# 3       0.52        0.59     0.94   0.57     0.92  0.53      0.92
# 4       0.36        0.55     0.88   0.64     1.00  0.67      0.85
# 5       0.68        0.36     0.94   0.50     0.69  0.67      0.69
# 6       0.56        0.73     1.00   0.50     0.92  0.40      0.69
# 7       0.80        0.55     0.69   0.43     0.77  0.73      0.85
# 8       0.52        0.64     0.94   0.64     0.77  0.60      0.85
# 9       0.48        0.27     0.94   0.64     0.92  0.47      0.77
# 10      0.48        0.41     0.81   0.36     0.62  0.33      0.92
# 11      0.32        0.36     0.81   0.50     0.54  0.47      1.00

# %%
import seaborn as sns

sns.heatmap(newdf, annot=True, cmap="crest")
# Out:
# <AxesSubplot:xlabel='class', ylabel='layer'>

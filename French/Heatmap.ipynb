# %%
import pandas as pd

layers = 12
df = pd.DataFrame()
for layer in range(layers):
    file = f'./results/wav2vecbase_perclass_{layer}.csv '
    data = pd.read_csv(file)
    data['layer'] = layer
    df = pd.concat([data, df], ignore_index=True)
df['accuracy'] = df['accuracy'].round(2)
df.head()
# Out:
#      class  accuracy  layer
# 0      Joy      0.07     11
# 1     Fear      0.17     11
# 2  Sadness      0.38     11
# 3    Anger      0.04     11
# 4  Disgust      0.63     11

# %%
newdf = pd.pivot(df, index='layer', columns='class', values='accuracy')
newdf = newdf[['Joy', 'Fear', 'Sadness', 'Anger', 'Disgust', 'Neutral', 'Surprise']]
newdf
# Out:
# class   Joy  Fear  Sadness  Anger  Disgust  Neutral  Surprise
# layer
# 0      0.24  0.75     0.65   0.46     0.60     0.50      0.43
# 1      0.38  0.67     0.62   0.57     0.53     0.75      0.63
# 2      0.24  0.79     0.82   0.75     0.77     0.88      0.74
# 3      0.62  0.67     0.79   0.86     0.87     0.88      0.54
# 4      0.59  0.79     0.76   0.68     0.77     1.00      0.77
# 5      0.52  0.58     0.76   0.93     0.67     0.62      0.54
# 6      0.66  0.62     0.68   0.71     0.57     1.00      0.71
# 7      0.55  0.58     0.53   0.96     0.63     1.00      0.69
# 8      0.62  0.71     0.53   0.79     0.60     0.88      0.49
# 9      0.41  0.75     0.68   0.64     0.40     0.75      0.37
# 10     0.07  0.00     0.09   0.43     0.23     1.00      0.26
# 11     0.07  0.17     0.38   0.04     0.63     0.62      0.00

# %%
import seaborn as sns

sns.heatmap(newdf, annot=True, cmap="crest")
# Out:
# <AxesSubplot:xlabel='class', ylabel='layer'>
